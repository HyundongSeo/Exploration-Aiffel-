# %%
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Out:
# --2022-04-08 01:32:28--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.170.1
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.170.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327699796 (313M) [application/zip]
# Saving to: ‘data_semantics.zip.2’
#
# data_semantics.zip. 100%[===================>] 312.52M  21.0MB/s    in 18s
#
# 2022-04-08 01:32:46 (17.8 MB/s) - ‘data_semantics.zip.2’ saved [327699796/327699796]

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.backend import int_shape

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
import os

dir_path = os.getenv('HOME')+'/aiffel/semantic_segmentation/data/training'

augmentation = build_augmentation()
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation(**image_data, is_train=False)
    processed = augmentation(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=4,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
def get_crop_shape(target, refer):
    # width, the 3rd dimension
    cw = target[2] - refer[2]
    assert (cw >= 0)
    if cw % 2 != 0:
        cw1, cw2 = int(cw/2), int(cw/2) + 1
    else:
        cw1, cw2 = int(cw/2), int(cw/2)
    # height, the 2nd dimension
    ch = target[1] - refer[1]
    assert (ch >= 0)
    if ch % 2 != 0:
        ch1, ch2 = int(ch/2), int(ch/2) + 1
    else:
        ch1, ch2 = int(ch/2), int(ch/2)

    return (ch1, ch2), (cw1, cw2)

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %%
def Unet_model(input_shape=(224, 224, 3), filters= [64, 128, 256, 512, 1024], kernel=3):
    inputs = Input(input_shape)
    x = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b1_conv1')(inputs)
    b1 = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b1_conv2')(x)
    
    x = MaxPooling2D(pool_size=(2,2), name='b2_pool')(b1)
    x = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b2_conv1')(x)
    b2 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b2_conv2')(x)
    
    x = MaxPooling2D(pool_size=(2,2), name='b3_pool')(b2)
    x = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b3_conv1')(x)
    b3 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b3_conv2')(x)
    
    x = MaxPooling2D(pool_size=(2,2), name='b4_pool')(b3)
    x = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b4_conv1')(x)
    b4 = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b4_conv2')(x)
    
    x = MaxPooling2D(pool_size=(2,2), name='b5_pool')(b4)
    x = Dropout(0.5)(x)
    x = Conv2D(filters[4], kernel, activation='relu', padding='same',kernel_initializer='he_normal', name='b5_conv1')(x)
    
    x = Conv2DTranspose(filters[3], (2, 2), strides=(2, 2), padding='valid', name='u1_convTran')(x)
    ch, cw = get_crop_shape(int_shape(b4), int_shape(x))
    r1 = Cropping2D(cropping=(ch, cw), name='u1_resize')(b4)
    x = concatenate([r1,x], axis = 3, name='u1_merge')
    x = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u1_conv1')(x)
    x = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u1_conv2')(x)
    
    x = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u2_convTran')(x)
    ch, cw = get_crop_shape(int_shape(b3), int_shape(x))
    r2 = Cropping2D(cropping=(ch, cw), name='u2_resize')(b3)
    x = concatenate([r2,x], axis = 3, name='u2_merge')
    x = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u2_conv1')(x)
    x = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u2_conv2')(x)
    
    x = Conv2DTranspose(filters[1], (2, 2), strides=(2, 2), padding='valid', name='u3_convTran')(x)
    ch, cw = get_crop_shape(int_shape(b2), int_shape(x))
    r3 = Cropping2D(cropping=(ch, cw), name='u3_resize')(b2)
    x = concatenate([r3,x], axis = 3, name='u3_merge')
    x = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u3_conv1')(x)
    x = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u3_conv2')(x)
    
    x = Conv2DTranspose(filters[0], (2, 2), strides=(2, 2), padding='valid', name='u4_convTran')(x)
    ch, cw = get_crop_shape(int_shape(b1), int_shape(x))
    r4 = Cropping2D(cropping=(ch, cw ), name='u4_resize')(b1)
    x = concatenate([r4,x], axis = 3, name='u4_merge')
    x = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u4_conv1')(x)
    x = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='u4_conv2')(x)
    x = Conv2D(2, kernel, activation='relu', padding='same',kernel_initializer='he_normal', name='u4_conv3')(x)
    x = Conv2D(1, 1, activation='sigmoid')(x)
    output = tf.image.resize(x, (inputs.shape[1], inputs.shape[2]), name='output')
    
    model = Model(inputs = inputs, outputs = output)
    return model

# %%
u_model = Unet_model()
u_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# b1_conv1 (Conv2D)               (None, 222, 222, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# b1_conv2 (Conv2D)               (None, 220, 220, 64) 36928       b1_conv1[0][0]
# __________________________________________________________________________________________________
# b2_pool (MaxPooling2D)          (None, 110, 110, 64) 0           b1_conv2[0][0]
# __________________________________________________________________________________________________
# b2_conv1 (Conv2D)               (None, 108, 108, 128 73856       b2_pool[0][0]
# __________________________________________________________________________________________________
# b2_conv2 (Conv2D)               (None, 106, 106, 128 147584      b2_conv1[0][0]
# __________________________________________________________________________________________________
# b3_pool (MaxPooling2D)          (None, 53, 53, 128)  0           b2_conv2[0][0]
# __________________________________________________________________________________________________
# b3_conv1 (Conv2D)               (None, 51, 51, 256)  295168      b3_pool[0][0]
# __________________________________________________________________________________________________
# b3_conv2 (Conv2D)               (None, 49, 49, 256)  590080      b3_conv1[0][0]
# __________________________________________________________________________________________________
# b4_pool (MaxPooling2D)          (None, 24, 24, 256)  0           b3_conv2[0][0]
# __________________________________________________________________________________________________
# b4_conv1 (Conv2D)               (None, 22, 22, 512)  1180160     b4_pool[0][0]
# __________________________________________________________________________________________________
# b4_conv2 (Conv2D)               (None, 20, 20, 512)  2359808     b4_conv1[0][0]
# __________________________________________________________________________________________________
# b5_pool (MaxPooling2D)          (None, 10, 10, 512)  0           b4_conv2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 10, 10, 512)  0           b5_pool[0][0]
# __________________________________________________________________________________________________
# b5_conv1 (Conv2D)               (None, 10, 10, 1024) 4719616     dropout[0][0]
# __________________________________________________________________________________________________
# u1_resize (Cropping2D)          (None, 20, 20, 512)  0           b4_conv2[0][0]
# __________________________________________________________________________________________________
# u1_convTran (Conv2DTranspose)   (None, 20, 20, 512)  2097664     b5_conv1[0][0]
# __________________________________________________________________________________________________
# u1_merge (Concatenate)          (None, 20, 20, 1024) 0           u1_resize[0][0]
#                                                                  u1_convTran[0][0]
# __________________________________________________________________________________________________
# u1_conv1 (Conv2D)               (None, 18, 18, 512)  4719104     u1_merge[0][0]
# __________________________________________________________________________________________________
# u1_conv2 (Conv2D)               (None, 16, 16, 512)  2359808     u1_conv1[0][0]
# __________________________________________________________________________________________________
# u2_resize (Cropping2D)          (None, 32, 32, 256)  0           b3_conv2[0][0]
# __________________________________________________________________________________________________
# u2_convTran (Conv2DTranspose)   (None, 32, 32, 256)  524544      u1_conv2[0][0]
# __________________________________________________________________________________________________
# u2_merge (Concatenate)          (None, 32, 32, 512)  0           u2_resize[0][0]
#                                                                  u2_convTran[0][0]
# __________________________________________________________________________________________________
# u2_conv1 (Conv2D)               (None, 30, 30, 256)  1179904     u2_merge[0][0]
# __________________________________________________________________________________________________
# u2_conv2 (Conv2D)               (None, 28, 28, 256)  590080      u2_conv1[0][0]
# __________________________________________________________________________________________________
# u3_resize (Cropping2D)          (None, 56, 56, 128)  0           b2_conv2[0][0]
# __________________________________________________________________________________________________
# u3_convTran (Conv2DTranspose)   (None, 56, 56, 128)  131200      u2_conv2[0][0]
# __________________________________________________________________________________________________
# u3_merge (Concatenate)          (None, 56, 56, 256)  0           u3_resize[0][0]
#                                                                  u3_convTran[0][0]
# __________________________________________________________________________________________________
# u3_conv1 (Conv2D)               (None, 54, 54, 128)  295040      u3_merge[0][0]
# __________________________________________________________________________________________________
# u3_conv2 (Conv2D)               (None, 52, 52, 128)  147584      u3_conv1[0][0]
# __________________________________________________________________________________________________
# u4_resize (Cropping2D)          (None, 104, 104, 64) 0           b1_conv2[0][0]
# __________________________________________________________________________________________________
# u4_convTran (Conv2DTranspose)   (None, 104, 104, 64) 32832       u3_conv2[0][0]
# __________________________________________________________________________________________________
# u4_merge (Concatenate)          (None, 104, 104, 128 0           u4_resize[0][0]
#                                                                  u4_convTran[0][0]
# __________________________________________________________________________________________________
# u4_conv1 (Conv2D)               (None, 102, 102, 64) 73792       u4_merge[0][0]
# __________________________________________________________________________________________________
# u4_conv2 (Conv2D)               (None, 100, 100, 64) 36928       u4_conv1[0][0]
# __________________________________________________________________________________________________
# u4_conv3 (Conv2D)               (None, 100, 100, 2)  1154        u4_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 100, 1)  3           u4_conv3[0][0]
# __________________________________________________________________________________________________
# tf.image.resize (TFOpLambda)    (None, 224, 224, 1)  0           conv2d[0][0]
# ==================================================================================================
# Total params: 21,594,629
# Trainable params: 21,594,629
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
u_model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
history = u_model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '\seg_model_unet.h5'
u_model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 43/43 [==============================] - 42s 108ms/step - loss: 0.5242 - val_loss: 0.3038
# Epoch 2/100
# 43/43 [==============================] - 4s 101ms/step - loss: 0.2763 - val_loss: 0.3038
# Epoch 3/100
# 43/43 [==============================] - 4s 98ms/step - loss: 0.2926 - val_loss: 0.3037
# Epoch 4/100
# 43/43 [==============================] - 4s 98ms/step - loss: 0.2757 - val_loss: 0.3037
# Epoch 5/100
# 43/43 [==============================] - 4s 98ms/step - loss: 0.2749 - val_loss: 0.3036
# Epoch 6/100
# 43/43 [==============================] - 4s 98ms/step - loss: 0.2813 - val_loss: 0.3035
# Epoch 7/100
# 43/43 [==============================] - 4s 99ms/step - loss: 0.2832 - val_loss: 0.3034
# Epoch 8/100
# 43/43 [==============================] - 4s 98ms/step - loss: 0.2911 - val_loss: 0.3034
# Epoch 9/100
# 43/43 [==============================] - 4s 99ms/step - loss: 0.2791 - val_loss: 0.3033
# Epoch 10/100
# 43/43 [==============================] - 4s 99ms/step - loss: 0.2873 - val_loss: 0.3032
# Epoch 11/100
# 43/43 [==============================] - 4s 99ms/step - loss: 0.2980 - val_loss: 0.3031
# Epoch 12/100
# 43/43 [==============================] - 4s 99ms/step - loss: 0.2822 - val_loss: 0.3030
# Epoch 13/100
# 43/43 [==============================] - 4s 100ms/step - loss: 0.2627 - val_loss: 0.3029
# Epoch 14/100
# 43/43 [==============================] - 4s 100ms/step - loss: 0.2956 - val_loss: 0.3028
# Epoch 15/100
# 43/43 [==============================] - 4s 100ms/step - loss: 0.2640 - val_loss: 0.3027
# Epoch 16/100
# 43/43 [==============================] - 4s 100ms/step - loss: 0.2773 - val_loss: 0.3026
# Epoch 17/100
# 43/43 [==============================] - 4s 101ms/step - loss: 0.2915 - val_loss: 0.3025
# Epoch 18/100
# 43/43 [==============================] - 4s 101ms/step - loss: 0.2806 - val_loss: 0.3024
# Epoch 19/100
# 43/43 [==============================] - 4s 101ms/step - loss: 0.2795 - val_loss: 0.3022
# Epoch 20/100
# 43/43 [==============================] - 4s 101ms/step - loss: 0.2926 - val_loss: 0.3021
# Epoch 21/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2797 - val_loss: 0.3020
# Epoch 22/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2553 - val_loss: 0.3019
# Epoch 23/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2725 - val_loss: 0.3017
# Epoch 24/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2768 - val_loss: 0.3016
# Epoch 25/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2828 - val_loss: 0.3015
# Epoch 26/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2646 - val_loss: 0.3014
# Epoch 27/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2878 - val_loss: 0.3012
# Epoch 28/100
# 43/43 [==============================] - 5s 104ms/step - loss: 0.2790 - val_loss: 0.3011
# Epoch 29/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2835 - val_loss: 0.3010
# Epoch 30/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2905 - val_loss: 0.3008
# Epoch 31/100
# 43/43 [==============================] - 4s 104ms/step - loss: 0.2955 - val_loss: 0.3007
# Epoch 32/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2873 - val_loss: 0.3006
# Epoch 33/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2890 - val_loss: 0.3005
# Epoch 34/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2694 - val_loss: 0.3003
# Epoch 35/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.3007 - val_loss: 0.3002
# Epoch 36/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2712 - val_loss: 0.3001
# Epoch 37/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2728 - val_loss: 0.2999
# Epoch 38/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2837 - val_loss: 0.2998
# Epoch 39/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2918 - val_loss: 0.2996
# Epoch 40/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2760 - val_loss: 0.2995
# Epoch 41/100
# 43/43 [==============================] - 4s 102ms/step - loss: 0.2853 - val_loss: 0.2994
# Epoch 42/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2835 - val_loss: 0.2992
# Epoch 43/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2986 - val_loss: 0.2991
# Epoch 44/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2872 - val_loss: 0.2990
# Epoch 45/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2897 - val_loss: 0.2988
# Epoch 46/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2888 - val_loss: 0.2987
# Epoch 47/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.3063 - val_loss: 0.2986
# Epoch 48/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2848 - val_loss: 0.2984
# Epoch 49/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2750 - val_loss: 0.2983
# Epoch 50/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2688 - val_loss: 0.2981
# Epoch 51/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2944 - val_loss: 0.2980
# Epoch 52/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2853 - val_loss: 0.2979
# Epoch 53/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2681 - val_loss: 0.2977
# Epoch 54/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2761 - val_loss: 0.2976
# Epoch 55/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2814 - val_loss: 0.2974
# Epoch 56/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2927 - val_loss: 0.2973
# Epoch 57/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2859 - val_loss: 0.2972
# Epoch 58/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2637 - val_loss: 0.2970
# Epoch 59/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2513 - val_loss: 0.2969
# Epoch 60/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2705 - val_loss: 0.2967
# Epoch 61/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2821 - val_loss: 0.2966
# Epoch 62/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2795 - val_loss: 0.2964
# Epoch 63/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2679 - val_loss: 0.2963
# Epoch 64/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2889 - val_loss: 0.2962
# Epoch 65/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2746 - val_loss: 0.2960
# Epoch 66/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2661 - val_loss: 0.2959
# Epoch 67/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.3003 - val_loss: 0.2958
# Epoch 68/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2866 - val_loss: 0.2956
# Epoch 69/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2728 - val_loss: 0.2955
# Epoch 70/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2785 - val_loss: 0.2954
# Epoch 71/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2865 - val_loss: 0.2952
# Epoch 72/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2915 - val_loss: 0.2951
# Epoch 73/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2937 - val_loss: 0.2950
# Epoch 74/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2599 - val_loss: 0.2948
# Epoch 75/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2766 - val_loss: 0.2947
# Epoch 76/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2753 - val_loss: 0.2946
# Epoch 77/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2682 - val_loss: 0.2944
# Epoch 78/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2738 - val_loss: 0.2943
# Epoch 79/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2682 - val_loss: 0.2941
# Epoch 80/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2593 - val_loss: 0.2940
# Epoch 81/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2751 - val_loss: 0.2939
# Epoch 82/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2815 - val_loss: 0.2937
# Epoch 83/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2636 - val_loss: 0.2936
# Epoch 84/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2867 - val_loss: 0.2935
# Epoch 85/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2721 - val_loss: 0.2933
# Epoch 86/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2723 - val_loss: 0.2932
# Epoch 87/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2635 - val_loss: 0.2931
# Epoch 88/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2760 - val_loss: 0.2929
# Epoch 89/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2942 - val_loss: 0.2928
# Epoch 90/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2780 - val_loss: 0.2927
# Epoch 91/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2514 - val_loss: 0.2926
# Epoch 92/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2765 - val_loss: 0.2924
# Epoch 93/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2711 - val_loss: 0.2923
# Epoch 94/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2728 - val_loss: 0.2922
# Epoch 95/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2764 - val_loss: 0.2921
# Epoch 96/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2798 - val_loss: 0.2919
# Epoch 97/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2736 - val_loss: 0.2918
# Epoch 98/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2566 - val_loss: 0.2917
# Epoch 99/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2558 - val_loss: 0.2916
# Epoch 100/100
# 43/43 [==============================] - 4s 103ms/step - loss: 0.2651 - val_loss: 0.2914

# %%
def Upp_model(input_shape=(224, 224, 3), filters= [0, 64, 128, 256, 512], kernel=3):
    inputs = Input(input_shape)
#     x0_0 = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b1_conv1')(inputs)
#     x0_0 = Conv2D(filters[0], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='b1_conv2')(x0_0)
    
    x1_0 = MaxPooling2D(pool_size=(2,2), name='x1_0_pool')(inputs)
    x1_0 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_0_conv1')(inputs)
    x1_0 = BatchNormalization()(x1_0)
    x1_0 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_0_conv2')(x1_0)
    x1_0 = BatchNormalization()(x1_0)
    
    x2_0 = MaxPooling2D(pool_size=(2,2), name='x2_0_pool')(x1_0)
    x2_0 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_0_conv1')(x2_0)
    x2_0 = BatchNormalization()(x2_0)
    x2_0 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_0_conv2')(x2_0)
    x2_0 = BatchNormalization()(x2_0)
    
    x3_0 = MaxPooling2D(pool_size=(2,2), name='x3_0_pool')(x2_0)
    x3_0 = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x3_0_conv1')(x3_0)
    x3_0 = BatchNormalization()(x3_0)
    x3_0 = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x3_0_conv2')(x3_0)
    x3_0 = BatchNormalization()(x3_0)
    
    x4_0 = MaxPooling2D(pool_size=(2,2), name='x4_0_pool')(x3_0)
    x4_0 = Conv2D(filters[4], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x4_0_conv1')(x4_0)
    x4_0 = BatchNormalization()(x4_0)
    x4_0 = Conv2D(filters[4], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x4_0_conv2')(x4_0)
    x4_0 = BatchNormalization()(x4_0)
    
    u4_0 = Conv2DTranspose(filters[3], (2, 2), strides=(2, 2), padding='valid', name='u4_0_convTran')(x4_0)
    r3_0 = tf.image.resize(x3_0, (u4_0.shape[1], u4_0.shape[2]), name='x3_0_resize')
    x3_1 = concatenate([r3_0, u4_0], axis = 3, name='x3_1_merge')
    x3_1 = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x3_1_conv1')(x3_1)
    x3_1 = Conv2D(filters[3], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x3_1_conv2')(x3_1)
    
    # 2-2로 감
    u3_0 = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u3_0_convTran')(x3_0)
    r2_0 = tf.image.resize(x2_0, (u3_0.shape[1], u3_0.shape[2]), name='a_r2_0_resize')
    x2_1 = concatenate([r2_0,u3_0], axis = 3, name='x2_1_merge')
    x2_1 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_1_conv1')(x2_1)
    x2_1 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_1_conv2')(x2_1)
    
    # origin
    u3_1 = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u3_1_convTran')(x3_1)
    r2_0 = tf.image.resize(x2_0, (u3_1.shape[1], u3_1.shape[2]), name='b_r2_0_resize')
    r2_1 = tf.image.resize(x2_1, (u3_1.shape[1], u3_1.shape[2]), name='b_r2_1_resize')
    x2_2 = concatenate([r2_0,r2_1, u3_1], axis = 3, name='x2_2_merge')
    x2_2 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_2_conv1')(x2_2)
    x2_2 = Conv2D(filters[2], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x2_2_conv2')(x2_2)
    
    # 1-3로 감
    u2_0 = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u2_0_convTran')(x2_0)
    r1_0 = tf.image.resize(x1_0, (u2_0.shape[1], u2_0.shape[2]), name='a_r1_0_resize')
    x1_1 = concatenate([r1_0,u2_0], axis = 3, name='x1_1_merge')
    x1_1 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_1_conv1')(x1_1)
    x1_1 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_1_conv2')(x1_1)
    
    # 1-3로 감
    u2_1 = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u2_1_convTran')(x2_1)
    r1_0 = tf.image.resize(x1_0, (u2_1.shape[1], u2_1.shape[2]), name='b_r1_0_resize')
    r1_1 = tf.image.resize(x1_1, (u2_1.shape[1], u2_1.shape[2]), name='b_r1_1_resize')
    x1_2 = concatenate([r1_0, r1_1, u2_1], axis = 3, name='x1_2_merge')
    x1_2 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_2_conv1')(x1_2)
    x1_2 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_2_conv2')(x1_2)
    
    # origin
    u2_2 = Conv2DTranspose(filters[2], (2, 2), strides=(2, 2), padding='valid', name='u2_2_convTran')(x2_2)
    r1_0 = tf.image.resize(x1_0, (u2_2.shape[1], u2_2.shape[2]), name='c_r1_0_resize')
    r1_1 = tf.image.resize(x1_1, (u2_2.shape[1], u2_2.shape[2]), name='c_r1_1_resize')
    r1_2 = tf.image.resize(x1_2, (u2_2.shape[1], u2_2.shape[2]), name='c_r1_2_resize')
    x1_3 = concatenate([r1_0, r1_1, r1_2, u2_2], axis = 3, name='x1_3_merge')
    x1_3 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_3_conv1')(x1_3)
    x1_3 = Conv2D(filters[1], kernel, activation='relu', padding='valid',kernel_initializer='he_normal', name='x1_3_conv2')(x1_3)
    x1_3 = Conv2D(2, kernel, activation='relu', padding='same',kernel_initializer='he_normal', name='x1_3_conv3')(x1_3)
    x1_3 = Conv2D(1, 1, activation='sigmoid')(x1_3)
    output = tf.image.resize(x1_3, (inputs.shape[1], inputs.shape[2]), name='output')
    model = Model(inputs = inputs, outputs = output)
    return model

# %%
upp_model = Upp_model()
upp_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# x1_0_conv1 (Conv2D)             (None, 222, 222, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 222, 222, 64) 256         x1_0_conv1[0][0]
# __________________________________________________________________________________________________
# x1_0_conv2 (Conv2D)             (None, 220, 220, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 220, 220, 64) 256         x1_0_conv2[0][0]
# __________________________________________________________________________________________________
# x2_0_pool (MaxPooling2D)        (None, 110, 110, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# x2_0_conv1 (Conv2D)             (None, 108, 108, 128 73856       x2_0_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 108, 108, 128 512         x2_0_conv1[0][0]
# __________________________________________________________________________________________________
# x2_0_conv2 (Conv2D)             (None, 106, 106, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 106, 106, 128 512         x2_0_conv2[0][0]
# __________________________________________________________________________________________________
# x3_0_pool (MaxPooling2D)        (None, 53, 53, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# x3_0_conv1 (Conv2D)             (None, 51, 51, 256)  295168      x3_0_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 51, 51, 256)  1024        x3_0_conv1[0][0]
# __________________________________________________________________________________________________
# x3_0_conv2 (Conv2D)             (None, 49, 49, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 49, 49, 256)  1024        x3_0_conv2[0][0]
# __________________________________________________________________________________________________
# x4_0_pool (MaxPooling2D)        (None, 24, 24, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# x4_0_conv1 (Conv2D)             (None, 22, 22, 512)  1180160     x4_0_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 22, 22, 512)  2048        x4_0_conv1[0][0]
# __________________________________________________________________________________________________
# x4_0_conv2 (Conv2D)             (None, 20, 20, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 512)  2048        x4_0_conv2[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_5 (TFOpLambda)  (None, 212, 212, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# u2_0_convTran (Conv2DTranspose) (None, 212, 212, 128 65664       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_2 (TFOpLambda)  (None, 98, 98, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# u3_0_convTran (Conv2DTranspose) (None, 98, 98, 128)  131200      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_1 (TFOpLambda)  (None, 40, 40, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# u4_0_convTran (Conv2DTranspose) (None, 40, 40, 256)  524544      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# x1_1_merge (Concatenate)        (None, 212, 212, 192 0           tf.image.resize_5[0][0]
#                                                                  u2_0_convTran[0][0]
# __________________________________________________________________________________________________
# x2_1_merge (Concatenate)        (None, 98, 98, 256)  0           tf.image.resize_2[0][0]
#                                                                  u3_0_convTran[0][0]
# __________________________________________________________________________________________________
# x3_1_merge (Concatenate)        (None, 40, 40, 512)  0           tf.image.resize_1[0][0]
#                                                                  u4_0_convTran[0][0]
# __________________________________________________________________________________________________
# x1_1_conv1 (Conv2D)             (None, 210, 210, 64) 110656      x1_1_merge[0][0]
# __________________________________________________________________________________________________
# x2_1_conv1 (Conv2D)             (None, 96, 96, 128)  295040      x2_1_merge[0][0]
# __________________________________________________________________________________________________
# x3_1_conv1 (Conv2D)             (None, 38, 38, 256)  1179904     x3_1_merge[0][0]
# __________________________________________________________________________________________________
# x1_1_conv2 (Conv2D)             (None, 208, 208, 64) 36928       x1_1_conv1[0][0]
# __________________________________________________________________________________________________
# x2_1_conv2 (Conv2D)             (None, 94, 94, 128)  147584      x2_1_conv1[0][0]
# __________________________________________________________________________________________________
# x3_1_conv2 (Conv2D)             (None, 36, 36, 256)  590080      x3_1_conv1[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_6 (TFOpLambda)  (None, 188, 188, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_7 (TFOpLambda)  (None, 188, 188, 64) 0           x1_1_conv2[0][0]
# __________________________________________________________________________________________________
# u2_1_convTran (Conv2DTranspose) (None, 188, 188, 128 65664       x2_1_conv2[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_3 (TFOpLambda)  (None, 72, 72, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_4 (TFOpLambda)  (None, 72, 72, 128)  0           x2_1_conv2[0][0]
# __________________________________________________________________________________________________
# u3_1_convTran (Conv2DTranspose) (None, 72, 72, 128)  131200      x3_1_conv2[0][0]
# __________________________________________________________________________________________________
# x1_2_merge (Concatenate)        (None, 188, 188, 256 0           tf.image.resize_6[0][0]
#                                                                  tf.image.resize_7[0][0]
#                                                                  u2_1_convTran[0][0]
# __________________________________________________________________________________________________
# x2_2_merge (Concatenate)        (None, 72, 72, 384)  0           tf.image.resize_3[0][0]
#                                                                  tf.image.resize_4[0][0]
#                                                                  u3_1_convTran[0][0]
# __________________________________________________________________________________________________
# x1_2_conv1 (Conv2D)             (None, 186, 186, 64) 147520      x1_2_merge[0][0]
# __________________________________________________________________________________________________
# x2_2_conv1 (Conv2D)             (None, 70, 70, 128)  442496      x2_2_merge[0][0]
# __________________________________________________________________________________________________
# x1_2_conv2 (Conv2D)             (None, 184, 184, 64) 36928       x1_2_conv1[0][0]
# __________________________________________________________________________________________________
# x2_2_conv2 (Conv2D)             (None, 68, 68, 128)  147584      x2_2_conv1[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_8 (TFOpLambda)  (None, 136, 136, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_9 (TFOpLambda)  (None, 136, 136, 64) 0           x1_1_conv2[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_10 (TFOpLambda) (None, 136, 136, 64) 0           x1_2_conv2[0][0]
# __________________________________________________________________________________________________
# u2_2_convTran (Conv2DTranspose) (None, 136, 136, 128 65664       x2_2_conv2[0][0]
# __________________________________________________________________________________________________
# x1_3_merge (Concatenate)        (None, 136, 136, 320 0           tf.image.resize_8[0][0]
#                                                                  tf.image.resize_9[0][0]
#                                                                  tf.image.resize_10[0][0]
#                                                                  u2_2_convTran[0][0]
# __________________________________________________________________________________________________
# x1_3_conv1 (Conv2D)             (None, 134, 134, 64) 184384      x1_3_merge[0][0]
# __________________________________________________________________________________________________
# x1_3_conv2 (Conv2D)             (None, 132, 132, 64) 36928       x1_3_conv1[0][0]
# __________________________________________________________________________________________________
# x1_3_conv3 (Conv2D)             (None, 132, 132, 2)  1154        x1_3_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 132, 132, 1)  3           x1_3_conv3[0][0]
# __________________________________________________________________________________________________
# tf.image.resize_11 (TFOpLambda) (None, 224, 224, 1)  0           conv2d_1[0][0]
# ==================================================================================================
# Total params: 9,034,181
# Trainable params: 9,030,341
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(upp_model, to_file='./upp_model.png')

# %%
upp_model = Upp_model()
upp_model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
upp_model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '\seg_model_uppnet.h5'
upp_model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# /opt/conda/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 43/43 [==============================] - 18s 239ms/step - loss: 0.7010 - val_loss: 0.6913
# Epoch 2/100
# 43/43 [==============================] - 10s 229ms/step - loss: 0.6904 - val_loss: 0.6895
# Epoch 3/100
# 43/43 [==============================] - 10s 229ms/step - loss: 0.6884 - val_loss: 0.6876
# Epoch 4/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6866 - val_loss: 0.6858
# Epoch 5/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6847 - val_loss: 0.6839
# Epoch 6/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6828 - val_loss: 0.6821
# Epoch 7/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6808 - val_loss: 0.6803
# Epoch 8/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6791 - val_loss: 0.6784
# Epoch 9/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6772 - val_loss: 0.6766
# Epoch 10/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6755 - val_loss: 0.6748
# Epoch 11/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6737 - val_loss: 0.6731
# Epoch 12/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6717 - val_loss: 0.6713
# Epoch 13/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6702 - val_loss: 0.6695
# Epoch 14/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6681 - val_loss: 0.6677
# Epoch 15/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6666 - val_loss: 0.6660
# Epoch 16/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6649 - val_loss: 0.6642
# Epoch 17/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6628 - val_loss: 0.6625
# Epoch 18/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6610 - val_loss: 0.6607
# Epoch 19/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6585 - val_loss: 0.6589
# Epoch 20/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6576 - val_loss: 0.6572
# Epoch 21/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6559 - val_loss: 0.6555
# Epoch 22/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6536 - val_loss: 0.6537
# Epoch 23/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6529 - val_loss: 0.6520
# Epoch 24/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6508 - val_loss: 0.6503
# Epoch 25/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6493 - val_loss: 0.6486
# Epoch 26/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6467 - val_loss: 0.6469
# Epoch 27/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6457 - val_loss: 0.6452
# Epoch 28/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6436 - val_loss: 0.6435
# Epoch 29/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6423 - val_loss: 0.6419
# Epoch 30/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6401 - val_loss: 0.6402
# Epoch 31/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6387 - val_loss: 0.6385
# Epoch 32/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6361 - val_loss: 0.6368
# Epoch 33/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6348 - val_loss: 0.6351
# Epoch 34/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6330 - val_loss: 0.6335
# Epoch 35/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6317 - val_loss: 0.6318
# Epoch 36/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6307 - val_loss: 0.6302
# Epoch 37/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6264 - val_loss: 0.6285
# Epoch 38/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6254 - val_loss: 0.6268
# Epoch 39/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6239 - val_loss: 0.6252
# Epoch 40/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6217 - val_loss: 0.6235
# Epoch 41/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6221 - val_loss: 0.6219
# Epoch 42/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6182 - val_loss: 0.6203
# Epoch 43/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6191 - val_loss: 0.6187
# Epoch 44/100
# 43/43 [==============================] - 10s 243ms/step - loss: 0.6159 - val_loss: 0.6170
# Epoch 45/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6148 - val_loss: 0.6154
# Epoch 46/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6123 - val_loss: 0.6138
# Epoch 47/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6108 - val_loss: 0.6122
# Epoch 48/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6102 - val_loss: 0.6107
# Epoch 49/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6081 - val_loss: 0.6091
# Epoch 50/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6068 - val_loss: 0.6075
# Epoch 51/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6062 - val_loss: 0.6060
# Epoch 52/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6057 - val_loss: 0.6044
# Epoch 53/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.6027 - val_loss: 0.6029
# Epoch 54/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5990 - val_loss: 0.6013
# Epoch 55/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5988 - val_loss: 0.5998
# Epoch 56/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5987 - val_loss: 0.5982
# Epoch 57/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5942 - val_loss: 0.5967
# Epoch 58/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5931 - val_loss: 0.5951
# Epoch 59/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5916 - val_loss: 0.5936
# Epoch 60/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5905 - val_loss: 0.5920
# Epoch 61/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5873 - val_loss: 0.5905
# Epoch 62/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5871 - val_loss: 0.5890
# Epoch 63/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5866 - val_loss: 0.5875
# Epoch 64/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5827 - val_loss: 0.5859
# Epoch 65/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5836 - val_loss: 0.5844
# Epoch 66/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5820 - val_loss: 0.5830
# Epoch 67/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5807 - val_loss: 0.5815
# Epoch 68/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5799 - val_loss: 0.5800
# Epoch 69/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5782 - val_loss: 0.5785
# Epoch 70/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5772 - val_loss: 0.5771
# Epoch 71/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5732 - val_loss: 0.5756
# Epoch 72/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5726 - val_loss: 0.5741
# Epoch 73/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5706 - val_loss: 0.5727
# Epoch 74/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5682 - val_loss: 0.5712
# Epoch 75/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5683 - val_loss: 0.5697
# Epoch 76/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5662 - val_loss: 0.5683
# Epoch 77/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5667 - val_loss: 0.5668
# Epoch 78/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5640 - val_loss: 0.5654
# Epoch 79/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5638 - val_loss: 0.5640
# Epoch 80/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5597 - val_loss: 0.5625
# Epoch 81/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5598 - val_loss: 0.5611
# Epoch 82/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5568 - val_loss: 0.5597
# Epoch 83/100
# 43/43 [==============================] - 10s 228ms/step - loss: 0.5561 - val_loss: 0.5583
# Epoch 84/100
# 43/43 [==============================] - 10s 229ms/step - loss: 0.5549 - val_loss: 0.5562
# Epoch 85/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5522 - val_loss: 0.5554
# Epoch 86/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5521 - val_loss: 0.5540
# Epoch 87/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5492 - val_loss: 0.5526
# Epoch 88/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5502 - val_loss: 0.5512
# Epoch 89/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5458 - val_loss: 0.5498
# Epoch 90/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5450 - val_loss: 0.5484
# Epoch 91/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5452 - val_loss: 0.5470
# Epoch 92/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5428 - val_loss: 0.5456
# Epoch 93/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5430 - val_loss: 0.5443
# Epoch 94/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5425 - val_loss: 0.5429
# Epoch 95/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5396 - val_loss: 0.5416
# Epoch 96/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5366 - val_loss: 0.5402
# Epoch 97/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5378 - val_loss: 0.5388
# Epoch 98/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5364 - val_loss: 0.5375
# Epoch 99/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5319 - val_loss: 0.5361
# Epoch 100/100
# 43/43 [==============================] - 10s 227ms/step - loss: 0.5308 - val_loss: 0.5348

# %%
def get_output(model, preproc, image_path, output_path):
     origin_img = imread(image_path)
     data = {"image":origin_img}
     processed = preproc(**data)
     output = model(np.expand_dims(processed["image"]/255,axis=0))
     output = (output[0].numpy()>0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
     output = Image.fromarray(output)
     background = Image.fromarray(origin_img).convert('RGBA')
     output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
     output = Image.blend(background, output, alpha=0.5)
     output.show()
     return output

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()  
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
i = 0    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     u_model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'/result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7F25E041B8B0>
# IoU : 0.000000
# 0.0

# %%
i = 0    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     upp_model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'/result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x7F26B139F0A0>
# IoU : 0.000000
# 0.0

# %% [markdown]
# ## 결과

# %% [markdown]
# 모델 구축 및 훈련까지 진행했는데 왜인지 모델 적용이 실패하였다.
